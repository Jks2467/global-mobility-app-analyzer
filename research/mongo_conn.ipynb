# %%
import pymongo
from dotenv import load_dotenv
import os
import pandas as pd

# %%
load_dotenv("../.env")
# Out:
# True

# %%
CONN_STR = os.environ['CONN_STRING']

# %%
try:
    client = pymongo.MongoClient(CONN_STR, serverSelectionTimeoutMS=5000)
    client.admin.command('ping')
    print("✅ MongoDB connection successful")
except Exception as e:
    print("❌ MongoDB connection failed:", e)
# Out:
# ✅ MongoDB connection successful

# %%
f_p = "../artifacts/datasets/EasyVisa.csv"

# %%
df = pd.read_csv(f_p)

# %%
data = df.to_dict(orient='records')

# %%
len(data)
# Out:
# 25480

# %%
DB_NAME = os.environ['DB_NAME']
COLLECTION_NAME = os.environ['COLLECTION_NAME']

# %%
client = pymongo.MongoClient(CONN_STR)
db = client[DB_NAME]
collection = db[COLLECTION_NAME]

collection.insert_many(data)

# %%
# get data from mongo db

df2 = pd.DataFrame(list(collection.find()))

# %%
df2.head()
# Out:
#                         _id case_id continent education_of_employee  \
# 0  69c9519b1776dd3a7419c78b  EZYV01      Asia           High School
# 1  69c9519b1776dd3a7419c78c  EZYV02      Asia              Master's
# 2  69c9519b1776dd3a7419c78d  EZYV03      Asia            Bachelor's
# 3  69c9519b1776dd3a7419c78e  EZYV04      Asia            Bachelor's
# 4  69c9519b1776dd3a7419c78f  EZYV05    Africa              Master's
#
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 0                  N                     N            14513         2007
# 1                  Y                     N             2412         2002
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
#
#   region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                 West         592.2029         Hour                  Y
# 1            Northeast       83425.6500         Year                  Y
# 2                 West      122996.8600         Year                  Y
# 3                 West       83434.0300         Year                  Y
# 4                South      149907.3900         Year                  Y
#
#   case_status
# 0      Denied
# 1   Certified
# 2      Denied
# 3      Denied
# 4   Certified
